# %%
import numpy as np
import pandas as pd

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-f36b5757-8549-4fe9-be7a-5e600972f68e" name="files[]" multiple disabled />
#      <output id="result-f36b5757-8549-4fe9-be7a-5e600972f68e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving telco_data.csv.csv to telco_data.csv.csv

# %%
import io
df = pd.read_csv(io.StringIO(uploaded['telco_data.csv.csv'].decode('utf-8')))

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ...   DeviceProtection  \
# 0  No phone service             DSL             No  ...                 No
# 1                No             DSL            Yes  ...                Yes
# 2                No             DSL            Yes  ...                 No
# 3  No phone service             DSL            Yes  ...                Yes
# 4                No     Fiber optic             No  ...                 No
#
# ...

# %%
df.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges
# count    7043.000000  7043.000000     7043.000000
# mean        0.162147    32.371149       64.761692
# std         0.368612    24.559481       30.090047
# min         0.000000     0.000000       18.250000
# 25%         0.000000     9.000000       35.500000
# 50%         0.000000    29.000000       70.350000
# 75%         0.000000    55.000000       89.850000
# max         1.000000    72.000000      118.750000

# %%
df.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges
# count    7043.000000  7043.000000     7043.000000
# mean        0.162147    32.371149       64.761692
# std         0.368612    24.559481       30.090047
# min         0.000000     0.000000       18.250000
# 25%         0.000000     9.000000       35.500000
# 50%         0.000000    29.000000       70.350000
# 75%         0.000000    55.000000       89.850000
# max         1.000000    72.000000      118.750000

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import Imputer

# %%
df['gender']
# Out:
# 0       Female
# 1         Male
# 2         Male
# 3         Male
# 4       Female
# 5       Female
# 6         Male
# 7       Female
# 8       Female
# 9         Male
# 10        Male
# 11        Male
# 12        Male
# 13        Male
# 14        Male
# 15      Female
# 16      Female
# 17        Male
# 18      Female
# 19      Female
# 20        Male
# 21        Male
# 22        Male
# 23      Female
# 24        Male
# 25      Female
# 26        Male
# 27        Male
# 28        Male
# 29      Female
#          ...
# 7013    Female
# 7014      Male
# 7015      Male
# 7016    Female
# 7017    Female
# 7018      Male
# 7019    Female
# 7020      Male
# 7021      Male
# 7022      Male
# 7023    Female
# 7024      Male
# 7025    Female
# 7026    Female
# 7027      Male
# 7028    Female
# 7029    Female
# 7030    Female
# 7031      Male
# 7032      Male
# 7033      Male
# 7034    Female
# 7035      Male
# 7036    Female
# 7037    Female
# 7038      Male
# 7039    Female
# ...

# %%
df.dtypes.sample(21)
# Out:
# TotalCharges        float64
# MultipleLines        object
# PhoneService         object
# Dependents           object
# SeniorCitizen         int64
# PaperlessBilling     object
# gender               object
# Partner              object
# StreamingMovies      object
# TechSupport          object
# OnlineSecurity       object
# MonthlyCharges      float64
# DeviceProtection     object
# StreamingTV          object
# customerID           object
# PaymentMethod        object
# Contract             object
# tenure                int64
# InternetService      object
# Churn                object
# OnlineBackup         object
# dtype: object

# %%
predictors_without_categoricals = df.select_dtypes(exclude=['object'])

# %%
one_hot_encoded_training_predictors = pd.get_dummies(df,columns= ['gender', 'SeniorCitizen', 'Partner', 'Dependents',
        'PhoneService', 'MultipleLines', 'InternetService',
       'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
       'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
       'PaymentMethod','Churn'])

# %%
one_hot_encoded_training_predictors
# Out:
#       customerID  tenure  MonthlyCharges TotalCharges  gender_Female  \
# 0     7590-VHVEG       1           29.85        29.85              1
# 1     5575-GNVDE      34           56.95       1889.5              0
# 2     3668-QPYBK       2           53.85       108.15              0
# 3     7795-CFOCW      45           42.30      1840.75              0
# 4     9237-HQITU       2           70.70       151.65              1
# 5     9305-CDSKC       8           99.65        820.5              1
# 6     1452-KIOVK      22           89.10       1949.4              0
# 7     6713-OKOMC      10           29.75        301.9              1
# 8     7892-POOKP      28          104.80      3046.05              1
# 9     6388-TABGU      62           56.15      3487.95              0
# 10    9763-GRSKD      13           49.95       587.45              0
# 11    7469-LKBCI      16           18.95        326.8              0
# 12    8091-TTVAX      58          100.35       5681.1              0
# ...

# %%
list(one_hot_encoded_training_predictors)
# Out:
# ['customerID',
#  'tenure',
#  'MonthlyCharges',
#  'TotalCharges',
#  'gender_Female',
#  'gender_Male',
#  'SeniorCitizen_0',
#  'SeniorCitizen_1',
#  'Partner_No',
#  'Partner_Yes',
#  'Dependents_No',
#  'Dependents_Yes',
#  'PhoneService_No',
#  'PhoneService_Yes',
#  'MultipleLines_No',
#  'MultipleLines_No phone service',
#  'MultipleLines_Yes',
#  'InternetService_DSL',
#  'InternetService_Fiber optic',
#  'InternetService_No',
#  'OnlineSecurity_No',
#  'OnlineSecurity_No internet service',
#  'OnlineSecurity_Yes',
#  'OnlineBackup_No',
#  'OnlineBackup_No internet service',
#  'OnlineBackup_Yes',
#  'DeviceProtection_No',
#  'DeviceProtection_No internet service',
#  'DeviceProtection_Yes',
#  'TechSupport_No',
#  'TechSupport_No internet service',
#  'TechSupport_Yes',
#  'StreamingTV_No',
#  'StreamingTV_No internet service',
#  'StreamingTV_Yes',
#  'StreamingMovies_No',
#  'StreamingMovies_No internet service',
#  'StreamingMovies_Yes',
#  'Contract_Month-to-month',
# ...

# %%
one_hot_encoded_training_predictors.index
# Out:
# RangeIndex(start=0, stop=7043, step=1)

# %%
final_use = one_hot_encoded_training_predictors.astype('float32',copy=False,errors= 'ignore')

# %%
X = final_use[[
 'tenure',
 'MonthlyCharges',
 'TotalCharges',
 'gender_Female',
 'gender_Male',
 'SeniorCitizen_0',
 'SeniorCitizen_1',
 'Partner_No',
 'Partner_Yes',
 'Dependents_No',
 'Dependents_Yes',
 'PhoneService_No',
 'PhoneService_Yes',
 'MultipleLines_No',
 'MultipleLines_No phone service',
 'MultipleLines_Yes',
 'InternetService_DSL',
 'InternetService_Fiber optic',
 'InternetService_No',
 'OnlineSecurity_No',
 'OnlineSecurity_No internet service',
 'OnlineSecurity_Yes',
 'OnlineBackup_No',
 'OnlineBackup_No internet service',
 'OnlineBackup_Yes',
 'DeviceProtection_No',
 'DeviceProtection_No internet service',
 'DeviceProtection_Yes',
 'TechSupport_No',
 'TechSupport_No internet service',
 'TechSupport_Yes',
 'StreamingTV_No',
 'StreamingTV_No internet service',
 'StreamingTV_Yes',
 'StreamingMovies_No',
 'StreamingMovies_No internet service',
 'StreamingMovies_Yes',
 'Contract_Month-to-month',
 'Contract_One year',
 'Contract_Two year',
 'PaperlessBilling_No',
 'PaperlessBilling_Yes',
 'PaymentMethod_Bank transfer (automatic)',
 'PaymentMethod_Credit card (automatic)',
 'PaymentMethod_Electronic check',
 'PaymentMethod_Mailed check']]

# %%
y = final_use.Churn_Yes

# %%
X.dtypes.sample(21)
# Out:
# OnlineBackup_Yes                           float32
# StreamingMovies_No                         float32
# PaperlessBilling_Yes                       float32
# PaymentMethod_Bank transfer (automatic)    float32
# PhoneService_No                            float32
# StreamingTV_No internet service            float32
# gender_Male                                float32
# TechSupport_No                             float32
# StreamingTV_No                             float32
# Contract_One year                          float32
# Dependents_No                              float32
# OnlineBackup_No internet service           float32
# TechSupport_No internet service            float32
# Contract_Month-to-month                    float32
# PaperlessBilling_No                        float32
# MultipleLines_No                           float32
# InternetService_No                         float32
# PaymentMethod_Credit card (automatic)      float32
# ...

# %% [markdown]
# charge_new = pd.to_numeric(final_use['TotalCharges'], errors='coerce')

# %%
X['TotalCharges'] = pd.to_numeric(X['TotalCharges'], errors= 'coerce')
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
X.TotalCharges.dtype
# Out:
# dtype('float32')

# %%
X.dtypes.sample(21)
# Out:
# StreamingMovies_Yes                    float32
# OnlineBackup_No                        float32
# MonthlyCharges                         float32
# Dependents_No                          float32
# StreamingMovies_No internet service    float32
# OnlineBackup_No internet service       float32
# TotalCharges                           float32
# gender_Female                          float32
# PaymentMethod_Mailed check             float32
# Partner_Yes                            float32
# Contract_Two year                      float32
# MultipleLines_No                       float32
# InternetService_DSL                    float32
# PaperlessBilling_Yes                   float32
# MultipleLines_Yes                      float32
# PhoneService_No                        float32
# PaymentMethod_Electronic check         float32
# DeviceProtection_No                    float32
# Dependents_Yes                         float32
# StreamingTV_Yes                        float32
# ...

# %%
train_X, test_X, train_y, test_y = train_test_split(X.as_matrix(), y.as_matrix(), test_size=0.25)
my_imputer = Imputer()

# %%
from xgboost import XGBRegressor

my_model = XGBRegressor()
# Add silent=True to avoid printing out updates with each cycle
my_model.fit(train_X, train_y, verbose=False)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_child_weight=1, missing=None, n_estimators=100,
#        n_jobs=1, nthread=None, objective='reg:linear', random_state=0,
#        reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#        silent=True, subsample=1)

# %%
predictions = my_model.predict(test_X)

from sklearn.metrics import mean_absolute_error
print("Mean Absolute Error : " + str(mean_absolute_error(predictions, test_y)))
# Out:
# Mean Absolute Error : 0.27357846

# %%
from sklearn.metrics import accuracy_score

# %%
import sklearn
sklearn.metrics.fbeta_score(test_y, predictions.round(),1 , sample_weight=None)
# Out:
# 0.5772455089820359

# %%
accuracy_score(test_y, predictions.round() , normalize=True, sample_weight=None)
# Out:
# 0.7825099375354913

# %%
from sklearn.ensemble.partial_dependence import partial_dependence, plot_partial_dependence

# %%
my_plots = plot_partial_dependence(my_model,       
                                   features=[0, 2], # column numbers of plots we want to show
                                   X=X,            # raw predictors data.
                                   feature_names=['MonthlyCharges', 'TotalCharges', 'InternetService_DSL'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-27-7c2918d80b97> in <module>()
#       2                                    features=[0, 2], # column numbers of plots we want to show
#       3                                    X=X,            # raw predictors data.
# ----> 4                                    feature_names=['MonthlyCharges', 'TotalCharges', 'InternetService_DSL'])
#
# /usr/local/lib/python3.6/dist-packages/sklearn/ensemble/partial_dependence.py in plot_partial_dependence(gbrt, X, features, feature_names, label, n_cols, grid_resolution, percentiles, n_jobs, verbose, ax, line_kw, contour_kw, **fig_kw)
#     244
#     245     if not isinstance(gbrt, BaseGradientBoosting):
# --> 246         raise ValueError('gbrt has to be an instance of BaseGradientBoosting')
#     247     check_is_fitted(gbrt, 'estimators_')
#     248
#
# ...
